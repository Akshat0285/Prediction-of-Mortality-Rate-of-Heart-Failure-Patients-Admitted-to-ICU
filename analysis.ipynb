# %%
import matplotlib.pyplot as plt

# Count the number of datapoints in each class
class_counts = df['Class'].value_counts()

# Plot the histogram
plt.hist(class_counts.index, bins=len(class_counts))
plt.xlabel('Class')
plt.ylabel('Number of Datapoints')
plt.title('Histogram of Datapoints in Each Class')
plt.show()
# Out:
# Number of features: 48
# Number of datapoints: 1058
#    age  gendera        BMI  hypertensive  atrialfibrillation  CHD with no MI  \
# 0   83        2  21.551321             0                   0               0
# 1   72        2  53.018931             1                   1               0
# 2   74        2        NaN             1                   1               0
# 3   44        1  28.486719             0                   0               0
# 4   89        1        NaN             1                   1               0
#
#    diabetes  deficiencyanemias  depression  Hyperlipemia  ...  Blood sodium  \
# 0         0                  0           0             0  ...    133.230769
# 1         0                  0           0             1  ...    132.600000
# 2         0                  0           0             0  ...    138.666667
# 3         0                  0           0             0  ...    139.250000
# ...

# %%
missing_values = data.isnull().sum()
print(missing_values)

total_missing_values = missing_values.sum()
print("Total number of missing values:", total_missing_values)
# Out:
# age                           0
# gendera                       0
# BMI                         190
# hypertensive                  0
# atrialfibrillation            0
# CHD with no MI                0
# diabetes                      0
# deficiencyanemias             0
# depression                    0
# Hyperlipemia                  0
# Renal failure                 0
# COPD                          0
# heart rate                   12
# Systolic blood pressure      14
# Diastolic blood pressure     14
# Respiratory rate             12
# temperature                  18
# SP O2                        12
# Urine output                 34
# hematocrit                    0
# RBC                           0
# MCH                           0
# MCHC                          0
# MCV                           0
# RDW                           0
# Leucocyte                     0
# Platelets                     0
# Neutrophils                 122
# Basophils                   216
# ...

# %%
import matplotlib.pyplot as plt

# Create a new figure with a larger size
plt.figure(figsize=(10, 8))

# plt.imshow(correlation_matrix, cmap='', interpolation='nearest')
plt.imshow(correlation_matrix, cmap='hot', interpolation='nearest', vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.show()
